# %%
import sys
sys.path.append("../scripts")

# %%
from feature_engineering import feature_engineering_pipeline

# %%
# Call the feature engineering pipeline
filepath = '../data/data.csv'  
processed_data = feature_engineering_pipeline(filepath)

# %%
# Display the processed data
processed_data.head()
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId  ProductId    Amount     Value      TransactionStartTime  \
# 0  CustomerId_4406          1  0.092004  0.000101 2018-11-15 02:18:49+00:00
# 1  CustomerId_4406         19  0.091910  0.000002 2018-11-15 02:19:08+00:00
# 2  CustomerId_4683          0  0.091958  0.000050 2018-11-15 02:44:21+00:00
# 3   CustomerId_988         11  0.093750  0.002206 2018-11-15 03:32:55+00:00
# 4   CustomerId_988         19  0.091853  0.000065 2018-11-15 03:34:21+00:00
#
#    FraudResult  ...  ChannelId_ChannelId_5  PricingStrategy_1  \
# 0            0  ...                  False              False
# 1            0  ...                  False              False
# 2            0  ...                  False              False
# 3            0  ...                  False              False
# 4            0  ...                  False              False
#
#    PricingStrategy_2  PricingStrategy_4  Recency  Frequency   Monetary  \
# 0               True              False       89        119  10.947603
# 1               True              False       89        119  10.947603
# 2               True              False        9          2   0.183915
# 3               True              False       85         38   3.513670
# 4               True              False       85         38   3.513670
#
#        Size  RFMS_Score  RFMS_WoE
# 0  0.091997        Good -1.209419
# 1  0.091997        Good -1.209419
# 2  0.091958         Bad  0.292841
# 3  0.092465        Good -1.209419
# 4  0.092465        Good -1.209419
#
# [5 rows x 43 columns]
